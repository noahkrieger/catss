# %% [markdown]
# # DataLoader
#
# Working prototype of the data loader.  Will be converted to standard Python

# %%
from dataclasses import dataclass
from typing import Tuple, List, Optional
import textwrap
import re
import string
from glob import glob
import os.path

import pandas as pd

# %% [markdown]
# ### Convert Packard markup to the Greek Alphabet

# %%
# def make_markup_to_greek_converter():
#     english = string.ascii_uppercase + r"35)(|/\=+:'"

#     greek_lower = [''] * len(english)
#     greek_upper = [''] * len(english)
#     greek_lower[english.find('A')] = '\u03b1'
#     greek_upper[english.find('A')] = '\u0391'
    
#     greek_lower[english.find('B')] = '\u03b2'
#     greek_upper[english.find('B')] = '\u0392'
    
#     greek_lower[english.find('G')] = '\u03b3'
#     greek_upper[english.find('G')] = '\u0393'
    
#     greek_lower[english.find('D')] = '\u03b4'
#     greek_upper[english.find('D')] = '\u0394'
    
#     greek_lower[english.find('E')] = '\u03b5'
#     greek_upper[english.find('E')] = '\u0395'
    
#     greek_lower[english.find('V')] = '\u03dd'
#     greek_upper[english.find('V')] = '\u03dc'
    
#     greek_lower[english.find('Z')] = '\u03b6'
#     greek_upper[english.find('Z')] = '\u0396'
    
#     greek_lower[english.find('H')] = '\u03b7'
#     greek_upper[english.find('H')] = '\u0397'
    
#     greek_lower[english.find('Q')] = '\u03b8'
#     greek_upper[english.find('Q')] = '\u0398'
    
#     greek_lower[english.find('I')] = '\u03b9'
#     greek_upper[english.find('I')] = '\u0399'
    
#     greek_lower[english.find('K')] = '\u03ba'
#     greek_upper[english.find('K')] = '\u039a'
    
#     greek_lower[english.find('L')] = '\u03bb'
#     greek_upper[english.find('L')] = '\u039b'
    
#     greek_lower[english.find('M')] = '\u03bc'
#     greek_upper[english.find('M')] = '\u039c'
    
#     greek_lower[english.find('N')] = '\u03bd'
#     greek_upper[english.find('N')] = '\u039d'
    
#     greek_lower[english.find('C')] = '\u03be'
#     greek_upper[english.find('C')] = '\u039e'
    
#     greek_lower[english.find('O')] = '\u03bf'
#     greek_upper[english.find('O')] = '\u039f'
    
#     greek_lower[english.find('P')] = '\u03c0'
#     greek_upper[english.find('P')] = '\u03a0'
    
#     greek_lower[english.find('3')] = '\u03d9'
#     greek_upper[english.find('3')] = '\u03d8'
    
#     greek_lower[english.find('R')] = '\u03c1'
#     greek_upper[english.find('R')] = '\u03a1'
    
#     greek_lower[english.find('S')] = '\u03c3'
#     greek_upper[english.find('S')] = '\u03a3'
    
#     greek_lower[english.find('J')] = '\u03c2'
#     greek_upper[english.find('J')] = '\u03a3'  
    
#     greek_lower[english.find('T')] = '\u03c4'
#     greek_upper[english.find('T')] = '\u03a4'
    
#     greek_lower[english.find('U')] = '\u03c5'
#     greek_upper[english.find('U')] = '\u03a5'
    
#     greek_lower[english.find('F')] = '\u03c6'
#     greek_upper[english.find('F')] = '\u03a6'
    
#     greek_lower[english.find('X')] = '\u03c7'
#     greek_upper[english.find('X')] = '\u03a7'
    
#     greek_lower[english.find('Y')] = '\u03c8'
#     greek_upper[english.find('Y')] = '\u03a8'
    
#     greek_lower[english.find('W')] = '\u03c9'
#     greek_upper[english.find('W')] = '\u03a9'
    
#     greek_lower[english.find('5')] = '\u03e1'
#     greek_upper[english.find('5')] = '\u03e0'
    
#     greek_lower[english.find(')')] = '\u0313'
#     greek_upper[english.find(')')] = '\u0313'
#     greek_lower[english.find('(')] = '\u0314'
#     greek_upper[english.find('(')] = '\u0314'
#     greek_lower[english.find('|')] = '\u0345'
#     greek_upper[english.find('|')] = '\u0345'
#     greek_lower[english.find('/')] = '\u0301'
#     greek_upper[english.find('/')] = '\u0301'
#     greek_lower[english.find('\\')] = '\u0300'
#     greek_upper[english.find('\\')] = '\u0300'
#     greek_lower[english.find('=')] = '\u0342'
#     greek_upper[english.find('=')] = '\u0342'
#     greek_lower[english.find('+')] = '\u0308'
#     greek_upper[english.find('+')] = '\u0308'
#     greek_lower[english.find(':')] = '\u00B7'
#     greek_upper[english.find(':')] = '\u00B7'
#     greek_lower[english.find("'")] = '\u0384'
#     greek_upper[english.find("'")] = '\u0384'

#     greek_lower = ''.join(greek_lower)
#     greek_upper = ''.join(greek_upper)
    

#     def converter(english_str: str) -> str:
#         greek_str = ''
#         greek_ = greek_lower
#         for i in range(len(english_str)):
#             es = english_str[i]
#             if es == '*':
#                 greek_ = greek_upper
#                 continue
#             if es == 'S' and ((i == len(english_str) -1) or english_str[i+1] == ' '):
#                 es = 'J'
#             if es in english:
#                 greek_str += greek_[english.find(es)]
#             elif es == ' ':
#                 greek_str += ' '
#             else:
#                 greek_str += f'__{es}__'
#             greek_ = greek_lower
#         return greek_str
                                   
                                   
    
#     return converter


def make_markup_to_greek_converter():
    greek_lower = {}
    greek_upper = {}
    
    greek_lower['A'] = '\u03b1'
    greek_upper['A'] = '\u0391'
    
    greek_lower['B'] = '\u03b2'
    greek_upper['B'] = '\u0392'
    
    greek_lower['G'] = '\u03b3'
    greek_upper['G'] = '\u0393'
    
    greek_lower['D'] = '\u03b4'
    greek_upper['D'] = '\u0394'
    
    greek_lower['E'] = '\u03b5'
    greek_upper['E'] = '\u0395'
    
    greek_lower['V'] = '\u03dd'
    greek_upper['V'] = '\u03dc'
    
    greek_lower['Z'] = '\u03b6'
    greek_upper['Z'] = '\u0396'
    
    greek_lower['H'] = '\u03b7'
    greek_upper['H'] = '\u0397'
    
    greek_lower['Q'] = '\u03b8'
    greek_upper['Q'] = '\u0398'
    
    greek_lower['I'] = '\u03b9'
    greek_upper['I'] = '\u0399'
    
    greek_lower['K'] = '\u03ba'
    greek_upper['K'] = '\u039a'
    
    greek_lower['L'] = '\u03bb'
    greek_upper['L'] = '\u039b'
    
    greek_lower['M'] = '\u03bc'
    greek_upper['M'] = '\u039c'
    
    greek_lower['N'] = '\u03bd'
    greek_upper['N'] = '\u039d'
    
    greek_lower['C'] = '\u03be'
    greek_upper['C'] = '\u039e'
    
    greek_lower['O'] = '\u03bf'
    greek_upper['O'] = '\u039f'
    
    greek_lower['P'] = '\u03c0'
    greek_upper['P'] = '\u03a0'
    
    greek_lower['3'] = '\u03d9'
    greek_upper['3'] = '\u03d8'
    
    greek_lower['R'] = '\u03c1'
    greek_upper['R'] = '\u03a1'
    
    greek_lower['S'] = '\u03c3'
    greek_upper['S'] = '\u03a3'
    
    greek_lower['J'] = '\u03c2'
    greek_upper['J'] = '\u03a3'  
    
    greek_lower['T'] = '\u03c4'
    greek_upper['T'] = '\u03a4'
    
    greek_lower['U'] = '\u03c5'
    greek_upper['U'] = '\u03a5'
    
    greek_lower['F'] = '\u03c6'
    greek_upper['F'] = '\u03a6'
    
    greek_lower['X'] = '\u03c7'
    greek_upper['X'] = '\u03a7'
    
    greek_lower['Y'] = '\u03c8'
    greek_upper['Y'] = '\u03a8'
    
    greek_lower['W'] = '\u03c9'
    greek_upper['W'] = '\u03a9'
    
    greek_lower['5'] = '\u03e1'
    greek_upper['5'] = '\u03e0'
    
    greek_lower[')'] = '\u0313'
    greek_upper[')'] = '\u0313'
    
    greek_lower['('] = '\u0314'
    greek_upper['('] = '\u0314'
    
    greek_lower['|'] = '\u0345'
    greek_upper['|'] = '\u0345'
    
    greek_lower['/'] = '\u0301'
    greek_upper['/'] = '\u0301'
    
    greek_lower['\\'] = '\u0300'
    greek_upper['\\'] = '\u0300'
    
    greek_lower['='] = '\u0342'
    greek_upper['='] = '\u0342'
    
    greek_lower['+'] = '\u0308'
    greek_upper['+'] = '\u0308'
    
    greek_lower[':'] = '\u00B7'
    greek_upper[':'] = '\u00B7'
    
    greek_lower["'"] = '\u0384'
    greek_upper["'"] = '\u0384'

    greek_upper = {ord(k): ord(v) for k,v in greek_upper.items()}
    greek_lower = {ord(k): ord(v) for k,v in greek_lower.items()}

    

    def converter(english_str: str) -> str:
        greek_str = ''
        greek_ = greek_lower
        for i,c in enumerate(english_str):
            if c == '*':
                greek_ = greek_upper
                continue
            if c == 'S' and ((i == len(english_str) -1) or english_str[i+1] == ' '):
                c = 'J'
            greek_str += c.translate(greek_)
            greek_ = greek_lower
        return greek_str
    
    return converter



greek_converter = make_markup_to_greek_converter()

# %%
print(greek_converter(r'E)N A)RXH=| E)POI/HSEN O( QEO\S TO\N '))
# Out:
# ἐν ἀρχῇ ἐποίησεν ὁ θεὸς τὸν

# %% [markdown]
# ### Greek Morphology
#
# This first part loads the data into structures that are easier to process.

# %%
test_file = '../../source_files/catss/greek_morph/01.Gen.1.mlxx'

# %%
BOOK_CHAPTER_VERSE_PATTERN = re.compile('^(\S+)\s+(\S*):(\S+)\s*$')
BOOK_CHAPTER_PATTERN = re.compile('^(\S+)\s+(\S*)$')
BOOK_PATTERN = re.compile('^(\S+)\s*$')
TOKEN_PATTERN = re.compile('(.{25})(.{4})(.{7})(\S{1,17})\s*(\S*)')
BOOKS = {
            '1Sam/K': {'english_name': 'I Samuel', 
                'alternate_english_name': 'Kings I',
                'greek_name': 'Βασιλειῶν Α' + '\u0374'},
            'Gen': {'english_name': 'Genesis', 
                'alternate_english_name': None,
                'greek_name': 'Γένεσις'},
            'DanTh': {'english_name': 'Daniel Th (Theodotion)', 
                'alternate_english_name': None,
                'greek_name': 'Δανιήλ'},
            '2Esdr': {'english_name': '2 Esdras', 
                'alternate_english_name': 'Ezra-Nehemiah',
                'greek_name': 'Ἔσδρας Β' + '\u0374'},
            '2/4Kgs': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Ezek': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Jer': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'EpJer': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'BelTh': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Gen': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'PsSol': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Ps': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Mal': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            '1Mac': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Isa': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Ezek': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            '4Mac': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Zeph': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Sir': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Joel': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Wis': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'JoshA': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            '1Esdr': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Prov': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Jdt': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Dan': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'TobBA': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Lam': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Amos': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Hab': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Nah': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Deut': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'JoshB': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Job': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Obad': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'TobS': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Exod': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Hos': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Od': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Mic': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            '1/3Kgs': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Jonah': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'JudgA': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Ps': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Isa': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            '3Mac': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Sus': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            '2Mac': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Zech': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Lev': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Ruth': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Esth': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'JudgB': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Jer': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Num': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            '2Sam/K': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Bar': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Hag': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            '2Chr': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Qoh': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Cant': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            '1Chr': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'Bel': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''},
            'SusTh': {'english_name': '', 
                'alternate_english_name': '',
                'greek_name': ''}

}

@dataclass
class Meta():
    name: str
    language: str
    source: str    
    filename: str
    raw: str
    encoding: str
    offsets: Tuple[int, int]
    description: str
    license: str
    
    def __repr__(self):
        repr = f'Meta(name={self.name}, language={self.language}, source={self.source}, filename={self.filename}, raw={textwrap.shorten(self.raw, width=20)}, encoding={self.encoding},'
        repr += f'offsets={self.offsets}, description={self.description}, license={self.license})'
        return repr

@dataclass
class Token():
    lemma_transliteration: str
    type_code: str
    parse_code: str
    dictionary_form_transliteration: str
    word_number: int = 0
    lemma_original: Optional[str] = None
    dictionary_form_original: Optional[str] = None
    other_transliteration: Optional[str] = None
    other_original: Optional[str] = None
    meta: Optional[Meta] = None
    
    def to_greek(str):
        pass
    
    def __post_init__(self):
        if self.lemma_transliteration:
            self.lemma_original = greek_converter(self.lemma_transliteration)
        if self.dictionary_form_transliteration:
            self.dictionary_form_original = greek_converter(self.dictionary_form_transliteration)
        if self.other_transliteration:
            self.other_original = greek_converter(self.other_transliteration)
    
@dataclass 
class Sentence():
    tokens: List[Token]
    sentence_number: int = 0
    meta: Optional[Meta] = None
    
    def print_all(self, transliterated=True, original=True):
        if transliterated:
            print(' '.join([t.lemma_transliteration for t in self.tokens]))
        if original:
            print(' '.join([t.lemma_original for t in self.tokens]))

    
@dataclass
class Verse():
    sentences: List[Sentence]
    verse_number: str
    meta: Optional[Meta] = None
    
    def print_all(self, transliterated=True, original=True):
        for sentence in self.sentences:
            sentence.print_all(transliterated=transliterated, original=original)
    
    
@dataclass
class Chapter():
    verses: List[Verse]
    chapter_number: str
    meta: Optional[Meta] = None
    
    def print_all(self, transliterated=True, original=True):
        for verse in self.verses:
            print('Verse:', verse.verse_number)
            verse.print_all(transliterated=transliterated, original=original)
    
    
@dataclass      
class Book():
    chapters: List[Chapter]
    book_name: str
    meta: Optional[Meta] = None
    
    def print_all(self, transliterated=True, original=True):
        for chapter in self.chapters:
            print('Chapter:', chapter.chapter_number)
            chapter.print_all(transliterated=transliterated, original=original)
        
    
@dataclass        
class Document():
    books: List[Book]
    meta: Meta
    
    def print_all(self, transliterated=True, original=True):
        for book in self.books:
            print('Book:', book.book_name)
            book.print_all(transliterated=transliterated, original=original)
  
@dataclass
class Corpus():
    documents: List[Document]
    meta: Optional[Meta] = None
    

def load_morph_file(filename, name, language, source, encoding='UTF8', description=None, license=None, include_raw=False):
    raw = None
    if include_raw:
        with open(filename, 'r', encoding=encoding) as fd:
            raw = fd.read()
    
    document_meta = Meta(filename=filename, name=name, language=language, source=source, encoding=encoding, 
                offsets=(0,-1), description=description, license=None, raw=raw)
    
    books = []
    
    with open(filename, encoding=encoding) as fd:
        current_sentence = []
        current_book = []
        current_book_name = None
        current_sentence = []
        current_chapter_number = None
        current_chapter = []
        current_verse_number = None
        current_verse = []
        
        sentence_number = 0
        word_number = 0
        
        for i, line in enumerate(fd):
            line = line.strip()
            matched = False
            if match := BOOK_CHAPTER_VERSE_PATTERN.match(line):
                book_name, chapter_number, verse_number = match.groups()
                matched = True
            elif match := BOOK_CHAPTER_PATTERN.match(line):
                # print('BOOK_CHAPTER_PATTERN==>', line)
                book_name, chapter_number = match.groups()
                verse_number = None
                matched = True
            elif match := BOOK_PATTERN.match(line):
                # print('BOOK_PATTERN==>', line)
                book_name = match.group(1)
                chapter_number = verse_number = None
                matched = True
            if matched:
                word_number = 0
                if current_book_name is None:
                    current_book_name = book_name
                    current_chapter_number = chapter_number
                    current_verse_number = verse_number
                if current_verse_number != verse_number \
                        or current_chapter_number != chapter_number \
                        or current_book_name != book_name:
                    current_verse.append(Sentence(tokens=current_sentence, sentence_number=sentence_number))
                    current_sentence = []
                    current_chapter.append(Verse(sentences=current_verse, verse_number=current_verse_number))
                    current_verse = []
                    current_verse_number = verse_number
                if current_chapter_number != chapter_number or current_book_name != book_name:
                    current_book.append(Chapter(verses=current_chapter, chapter_number=current_chapter_number))
                    current_chapter = []
                    current_chapter_number = chapter_number
                if current_book_name != book_name:
                    if current_book_name:
                        books.append(Book(chapters=current_book, book_name=current_book_name))
                        current_book = []
                    current_book_name = book_name
                continue
            if len(line) == 0:
                if current_sentence:
                    current_verse.append(Sentence(tokens=current_sentence, sentence_number=sentence_number))
                    current_sentence = []
                    sentence_number += 1
                continue
            
            # current_sentence.append(line)
            if match := TOKEN_PATTERN.match(line):
                lemma_transliteration, type_code, parse_code, dictionary_form_transliteration, \
                    other_transliteration = match.groups()
                token = Token(lemma_transliteration=lemma_transliteration.strip(), 
                              type_code=type_code.strip(), 
                              parse_code=parse_code.strip(),
                              dictionary_form_transliteration=dictionary_form_transliteration,
                              other_transliteration=other_transliteration.strip())
                current_sentence.append(token)
                # print(token)
                word_number += 1
            else:
                print('NOT MATCH==>', line)
            
            # print(sentence_number, word_number, i,  line)
            
            
        if current_sentence:
            current_verse.append(Sentence(tokens=current_sentence, sentence_number=sentence_number))
        if current_verse:
            current_chapter.append(Verse(sentences=current_verse, verse_number=current_verse_number))
        if current_chapter:
            current_book.append(Chapter(verses=current_chapter, chapter_number=current_chapter_number))
        if current_book:
            books.append(Book(chapters=current_book, book_name=current_book_name))
            
        return Document(books=books, meta=document_meta)
                

def load_corpus(path='../../source_files/catss/greek_morph'):
    files = glob(os.path.join(path, '*.mlxx'))
    documents = []
    for file in files:
        name = re.match('\S*/\d\d\.(\S+).mlxx', file).group(1)
        print(file, name)
        documents.append(load_morph_file(file, name, 'greek', 'catss'))
    return Corpus(documents=documents)

# %%
BOOKS
# Out:
# {'1Sam/K': {'english_name': 'I Samuel',
#   'alternate_english_name': 'Kings I',
#   'greek_name': 'Βασιλειῶν Αʹ'},
#  'Gen': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'DanTh': {'english_name': 'Daniel Th (Theodotion)',
#   'alternate_english_name': '',
#   'greek_name': 'Δανιήλ'},
#  '2Esdr': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  '2/4Kgs': {'english_name': '',
#   'alternate_english_name': '',
#   'greek_name': ''},
#  'Ezek': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Jer': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'EpJer': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'BelTh': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'PsSol': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Ps': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Mal': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  '1Mac': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Isa': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  '4Mac': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Zeph': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Sir': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Joel': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Wis': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'JoshA': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  '1Esdr': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Prov': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Jdt': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Dan': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'TobBA': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Lam': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Amos': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Hab': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Nah': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Deut': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'JoshB': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Job': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Obad': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'TobS': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Exod': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Hos': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Od': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Mic': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  '1/3Kgs': {'english_name': '',
#   'alternate_english_name': '',
#   'greek_name': ''},
#  'Jonah': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'JudgA': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  '3Mac': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Sus': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  '2Mac': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Zech': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Lev': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Ruth': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Esth': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'JudgB': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Num': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  '2Sam/K': {'english_name': '',
#   'alternate_english_name': '',
#   'greek_name': ''},
#  'Bar': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Hag': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  '2Chr': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Qoh': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Cant': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  '1Chr': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'Bel': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''},
#  'SusTh': {'english_name': '', 'alternate_english_name': '', 'greek_name': ''}}

# %%
corpus = load_corpus()
# Out:
# ../../source_files/catss/greek_morph/12.1Sam.mlxx 1Sam
# ../../source_files/catss/greek_morph/01.Gen.1.mlxx Gen.1
# ../../source_files/catss/greek_morph/62.DanielTh.mlxx DanielTh
# ../../source_files/catss/greek_morph/19.2Esdras.mlxx 2Esdras
# ../../source_files/catss/greek_morph/15.2Kings.mlxx 2Kings
# ../../source_files/catss/greek_morph/57.Ezek1.mlxx Ezek1
# ../../source_files/catss/greek_morph/53.Jer2.mlxx Jer2
# ../../source_files/catss/greek_morph/55.EpJer.mlxx EpJer
# ../../source_files/catss/greek_morph/60.BelTh.mlxx BelTh
# ../../source_files/catss/greek_morph/02.Gen.2.mlxx Gen.2
# ../../source_files/catss/greek_morph/37.PsSol.mlxx PsSol
# ../../source_files/catss/greek_morph/29.Psalms2.mlxx Psalms2
# ../../source_files/catss/greek_morph/49.Malachi.mlxx Malachi
# ../../source_files/catss/greek_morph/24.1Macc.mlxx 1Macc
# ../../source_files/catss/greek_morph/51.Isaiah2.mlxx Isaiah2
# ../../source_files/catss/greek_morph/58.Ezek2.mlxx Ezek2
# ../../source_files/catss/greek_morph/27.4Macc.mlxx 4Macc
# ../../source_files/catss/greek_morph/46.Zeph.mlxx Zeph
# ../../source_files/catss/greek_morph/36.Sirach.mlxx Sirach
# ../../source_files/catss/greek_morph/41.Joel.mlxx Joel
# ../../source_files/catss/greek_morph/35.Wisdom.mlxx Wisdom
# ../../source_files/catss/greek_morph/08.JoshA.mlxx JoshA
# ../../source_files/catss/greek_morph/18.1Esdras.mlxx 1Esdras
# ../../source_files/catss/greek_morph/31.Proverbs.mlxx Proverbs
# ../../source_files/catss/greek_morph/21.Judith.mlxx Judith
# ../../source_files/catss/greek_morph/61.DanielOG.mlxx DanielOG
# ../../source_files/catss/greek_morph/22.TobitBA.mlxx TobitBA
# ../../source_files/catss/greek_morph/56.Lam.mlxx Lam
# ../../source_files/catss/greek_morph/40.Amos.mlxx Amos
# ../../source_files/catss/greek_morph/45.Habakkuk.mlxx Habakkuk
# ../../source_files/catss/greek_morph/44.Nahum.mlxx Nahum
# ../../source_files/catss/greek_morph/06.Deut.mlxx Deut
# ../../source_files/catss/greek_morph/07.JoshB.mlxx JoshB
# ../../source_files/catss/greek_morph/34.Job.mlxx Job
# ../../source_files/catss/greek_morph/43.Obadiah.mlxx Obadiah
# ../../source_files/catss/greek_morph/23.TobitS.mlxx TobitS
# ../../source_files/catss/greek_morph/03.Exod.mlxx Exod
# ../../source_files/catss/greek_morph/38.Hosea.mlxx Hosea
# ../../source_files/catss/greek_morph/30.Odes.mlxx Odes
# ../../source_files/catss/greek_morph/39.Micah.mlxx Micah
# ../../source_files/catss/greek_morph/14.1Kings.mlxx 1Kings
# ../../source_files/catss/greek_morph/42.Jonah.mlxx Jonah
# ../../source_files/catss/greek_morph/10.JudgesA.mlxx JudgesA
# ../../source_files/catss/greek_morph/28.Psalms1.mlxx Psalms1
# ../../source_files/catss/greek_morph/50.Isaiah1.mlxx Isaiah1
# ../../source_files/catss/greek_morph/26.3Macc.mlxx 3Macc
# ../../source_files/catss/greek_morph/63.SusOG.mlxx SusOG
# ../../source_files/catss/greek_morph/25.2Macc.mlxx 2Macc
# ../../source_files/catss/greek_morph/48.Zech.mlxx Zech
# ../../source_files/catss/greek_morph/04.Lev.mlxx Lev
# ../../source_files/catss/greek_morph/11.Ruth.mlxx Ruth
# ../../source_files/catss/greek_morph/20.Esther.mlxx Esther
# ../../source_files/catss/greek_morph/09.JudgesB.mlxx JudgesB
# ../../source_files/catss/greek_morph/52.Jer1.mlxx Jer1
# ../../source_files/catss/greek_morph/05.Num.mlxx Num
# ../../source_files/catss/greek_morph/13.2Sam.mlxx 2Sam
# ../../source_files/catss/greek_morph/54.Baruch.mlxx Baruch
# ../../source_files/catss/greek_morph/47.Haggai.mlxx Haggai
# ../../source_files/catss/greek_morph/17.2Chron.mlxx 2Chron
# ../../source_files/catss/greek_morph/32.Qoheleth.mlxx Qoheleth
# ../../source_files/catss/greek_morph/33.Canticles.mlxx Canticles
# ../../source_files/catss/greek_morph/16.1Chron.mlxx 1Chron
# ../../source_files/catss/greek_morph/59.BelOG.mlxx BelOG
# ../../source_files/catss/greek_morph/64.SusTh.mlxx SusTh

# %%
hex(ord("ʹ"))
# Out:
# '0x2b9'

# %%
gen = None
bk = None
for doc in corpus.documents:
    for book in doc.books:
        t = '    '
        print(f"{t*3}'{book.book_name}': {{'english_name': '', ")
        print(f"{t*4}'alternate_english_name': '',")
        print(f"{t*4}'greek_name': ''}},")
        # if book.book_name == 'PsSol':
        #     bk = book
        #     break
        # for chapter in book.chapters:
        #     print('\t', chapter.chapter_number)
# Out:
#             '1Sam/K': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Gen': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'DanTh': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             '2Esdr': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             '2/4Kgs': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Ezek': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Jer': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'EpJer': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'BelTh': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Gen': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'PsSol': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Ps': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Mal': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             '1Mac': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Isa': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Ezek': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             '4Mac': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Zeph': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Sir': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Joel': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Wis': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'JoshA': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             '1Esdr': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Prov': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Jdt': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Dan': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'TobBA': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Lam': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Amos': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Hab': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Nah': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Deut': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'JoshB': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Job': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Obad': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'TobS': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Exod': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Hos': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Od': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Mic': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             '1/3Kgs': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Jonah': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'JudgA': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Ps': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Isa': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             '3Mac': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Sus': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             '2Mac': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Zech': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Lev': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Ruth': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Esth': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'JudgB': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Jer': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Num': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             '2Sam/K': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Bar': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Hag': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             '2Chr': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Qoh': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Cant': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             '1Chr': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'Bel': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},
#             'SusTh': {'english_name': '',
#                 'alternate_english_name': '',
#                 'greek_name': ''},

# %%
for i, chapter in enumerate(bk.chapters):
    if i > 1:
        break
    for     
    for sent in chapter.sentences:
        print()
    print()
    print()
# Out:
# Chapter(verses=[Verse(sentences=[Sentence(tokens=[Token(lemma_transliteration='E)BO/HSA', type_code='VAI', parse_code='AAI1S', dictionary_form_transliteration='BOA/W', word_number=0, lemma_original='ἐβόησα', dictionary_form_original='βοάω', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='PRO\\S', type_code='P', parse_code='', dictionary_form_transliteration='PRO/S', word_number=0, lemma_original='πρὸς', dictionary_form_original='πρός', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='KU/RION', type_code='N2', parse_code='ASM', dictionary_form_transliteration='KU/RIOS', word_number=0, lemma_original='κύριον', dictionary_form_original='κύριος', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='E)N', type_code='P', parse_code='', dictionary_form_transliteration='E)N', word_number=0, lemma_original='ἐν', dictionary_form_original='ἐν', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='TW=|', type_code='RA', parse_code='DSN', dictionary_form_transliteration='O(', word_number=0, lemma_original='τῷ', dictionary_form_original='ὁ', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='QLI/BESQAI/', type_code='V1', parse_code='PMN', dictionary_form_transliteration='QLI/BW', word_number=0, lemma_original='θλίβεσθαί', dictionary_form_original='θλίβω', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='ME', type_code='RP', parse_code='AS', dictionary_form_transliteration='E)GW/', word_number=0, lemma_original='με', dictionary_form_original='ἐγώ', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='EI)S', type_code='P', parse_code='', dictionary_form_transliteration='EI)S', word_number=0, lemma_original='εἰς', dictionary_form_original='εἰς', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='TE/LOS', type_code='N3E', parse_code='ASN', dictionary_form_transliteration='TE/LOS', word_number=0, lemma_original='τέλος', dictionary_form_original='τέλος', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='PRO\\S', type_code='P', parse_code='', dictionary_form_transliteration='PRO/S', word_number=0, lemma_original='πρὸς', dictionary_form_original='πρός', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='TO\\N', type_code='RA', parse_code='ASM', dictionary_form_transliteration='O(', word_number=0, lemma_original='τὸν', dictionary_form_original='ὁ', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='QEO\\N', type_code='N2', parse_code='ASM', dictionary_form_transliteration='QEO/S', word_number=0, lemma_original='θεὸν', dictionary_form_original='θεός', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='E)N', type_code='P', parse_code='', dictionary_form_transliteration='E)N', word_number=0, lemma_original='ἐν', dictionary_form_original='ἐν', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='TW=|', type_code='RA', parse_code='DSN', dictionary_form_transliteration='O(', word_number=0, lemma_original='τῷ', dictionary_form_original='ὁ', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='E)PIQE/SQAI', type_code='VE', parse_code='AMN', dictionary_form_transliteration='TI/QHMI', word_number=0, lemma_original='ἐπιθέσθαι', dictionary_form_original='τίθημι', other_transliteration='E)PI', other_original='ἐπι', meta=None), Token(lemma_transliteration='A(MARTWLOU/S', type_code='A1B', parse_code='APM', dictionary_form_transliteration='A(MARTWLO/S', word_number=0, lemma_original='ἁμαρτωλούς', dictionary_form_original='ἁμαρτωλός', other_transliteration='', other_original=None, meta=None)], sentence_number=0, meta=Non ...
#
#
# Chapter(verses=[Verse(sentences=[Sentence(tokens=[Token(lemma_transliteration='YALMO\\S', type_code='N2', parse_code='NSM', dictionary_form_transliteration='YALMO/S', word_number=0, lemma_original='ψαλμὸς', dictionary_form_original='ψαλμός', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='TW=|', type_code='RA', parse_code='DSM', dictionary_form_transliteration='O(', word_number=0, lemma_original='τῷ', dictionary_form_original='ὁ', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='*SALWMWN', type_code='N', parse_code='DSM', dictionary_form_transliteration='*SALWMW/N', word_number=0, lemma_original='Σαλωμων', dictionary_form_original='Σαλωμών', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='PERI\\', type_code='P', parse_code='', dictionary_form_transliteration='PERI/', word_number=0, lemma_original='περὶ', dictionary_form_original='περί', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='*IEROUSALHM', type_code='N', parse_code='AS', dictionary_form_transliteration='*I)EROUSALH/M', word_number=0, lemma_original='Ιερουσαλημ', dictionary_form_original='Ἰερουσαλήμ', other_transliteration='', other_original=None, meta=None)], sentence_number=8, meta=None), Sentence(tokens=[], sentence_number=9, meta=None)], verse_number=None, meta=None)], chapter_number=None, meta=None)
#
#
# Chapter(verses=[Verse(sentences=[Sentence(tokens=[Token(lemma_transliteration='E)N', type_code='P', parse_code='', dictionary_form_transliteration='E)N', word_number=0, lemma_original='ἐν', dictionary_form_original='ἐν', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='TW=|', type_code='RA', parse_code='DSN', dictionary_form_transliteration='O(', word_number=0, lemma_original='τῷ', dictionary_form_original='ὁ', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='U(PERHFANEU/ESQAI', type_code='V1', parse_code='PMN', dictionary_form_transliteration='H)FANEU/OMAI', word_number=0, lemma_original='ὑπερηφανεύεσθαι', dictionary_form_original='ἠφανεύομαι', other_transliteration='U(PER', other_original='ὑπερ', meta=None), Token(lemma_transliteration='TO\\N', type_code='RA', parse_code='ASM', dictionary_form_transliteration='O(', word_number=0, lemma_original='τὸν', dictionary_form_original='ὁ', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='A(MARTWLO\\N', type_code='A1B', parse_code='ASM', dictionary_form_transliteration='A(MARTWLO/S', word_number=0, lemma_original='ἁμαρτωλὸν', dictionary_form_original='ἁμαρτωλός', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='E)N', type_code='P', parse_code='', dictionary_form_transliteration='E)N', word_number=0, lemma_original='ἐν', dictionary_form_original='ἐν', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='KRIW=|', type_code='N2', parse_code='DSM', dictionary_form_transliteration='KRIO/S', word_number=0, lemma_original='κριῷ', dictionary_form_original='κριός', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='KATE/BALE', type_code='VBI', parse_code='AAI3S', dictionary_form_transliteration='BA/LLW', word_number=0, lemma_original='κατέβαλε', dictionary_form_original='βάλλω', other_transliteration='KATA', other_original='κατα', meta=None), Token(lemma_transliteration='TEI/XH', type_code='N3E', parse_code='APN', dictionary_form_transliteration='TEI=XOS', word_number=0, lemma_original='τείχη', dictionary_form_original='τεῖχος', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='O)XURA/', type_code='A1A', parse_code='APN', dictionary_form_transliteration='O)XURO/S', word_number=0, lemma_original='ὀχυρά', dictionary_form_original='ὀχυρός', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='KAI\\', type_code='C', parse_code='', dictionary_form_transliteration='KAI/', word_number=0, lemma_original='καὶ', dictionary_form_original='καί', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='OU)K', type_code='D', parse_code='', dictionary_form_transliteration='OU)', word_number=0, lemma_original='οὐκ', dictionary_form_original='οὐ', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='E)KW/LUSAS', type_code='VAI', parse_code='AAI2S', dictionary_form_transliteration='KWLU/W', word_number=0, lemma_original='ἐκώλυσας', dictionary_form_original='κωλύω', other_transliteration='', other_original=None, meta=None)], sentence_number=9, meta=None), Sentence(tokens=[], sentence_number=10, meta=None)], verse_number='1', meta=None), Verse(sentences=[Sentence(tokens=[Token(lemma_transliteration='A)NE/BHSAN', type_code='VZI', parse_code='AAI3P', dictionary_form_transliteration='BAI/NW', word_number=0, lemma_original='ἀνέβησαν', dictionary_form_original='βαίνω', other_transliteration='A)NA', other_original='ἀνα', meta=None), Token(lemma_transliteration='E)PI\\', type_code='P', parse_code='', dictionary_form_transliteration='E)PI/', word_number=0, lemma_original='ἐπὶ', dictionary_form_original='ἐπί', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='TO\\', type_code='RA', ...
#
#
# Chapter(verses=[Verse(sentences=[Sentence(tokens=[Token(lemma_transliteration='YALMO\\S', type_code='N2', parse_code='NSM', dictionary_form_transliteration='YALMO/S', word_number=0, lemma_original='ψαλμὸς', dictionary_form_original='ψαλμός', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='TW=|', type_code='RA', parse_code='DSM', dictionary_form_transliteration='O(', word_number=0, lemma_original='τῷ', dictionary_form_original='ὁ', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='*SALWMWN', type_code='N', parse_code='DSM', dictionary_form_transliteration='*SALWMW/N', word_number=0, lemma_original='Σαλωμων', dictionary_form_original='Σαλωμών', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='PERI\\', type_code='P', parse_code='', dictionary_form_transliteration='PERI/', word_number=0, lemma_original='περὶ', dictionary_form_original='περί', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='DIKAI/WN', type_code='A1A', parse_code='GPM', dictionary_form_transliteration='DI/KAIOS', word_number=0, lemma_original='δικαίων', dictionary_form_original='δίκαιος', other_transliteration='', other_original=None, meta=None)], sentence_number=46, meta=None), Sentence(tokens=[], sentence_number=47, meta=None)], verse_number=None, meta=None)], chapter_number=None, meta=None)
#
#
# Chapter(verses=[Verse(sentences=[Sentence(tokens=[Token(lemma_transliteration='I(/NA', type_code='D', parse_code='', dictionary_form_transliteration='I(/NA', word_number=0, lemma_original='ἵνα', dictionary_form_original='ἵνα', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='TI/', type_code='RI', parse_code='ASN', dictionary_form_transliteration='TI/S', word_number=0, lemma_original='τί', dictionary_form_original='τίς', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='U(PNOI=S', type_code='N2', parse_code='DPM', dictionary_form_transliteration='U(/PNOS', word_number=0, lemma_original='ὑπνοῖς', dictionary_form_original='ὕπνος', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='YUXH/', type_code='N1', parse_code='NSF', dictionary_form_transliteration='YUXH/', word_number=0, lemma_original='ψυχή', dictionary_form_original='ψυχή', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='KAI\\', type_code='C', parse_code='', dictionary_form_transliteration='KAI/', word_number=0, lemma_original='καὶ', dictionary_form_original='καί', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='OU)K', type_code='D', parse_code='', dictionary_form_transliteration='OU)', word_number=0, lemma_original='οὐκ', dictionary_form_original='οὐ', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='EU)LOGEI=S', type_code='V2', parse_code='PAI2S', dictionary_form_transliteration='EU)LOGE/W', word_number=0, lemma_original='εὐλογεῖς', dictionary_form_original='εὐλογέω', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='TO\\N', type_code='RA', parse_code='ASM', dictionary_form_transliteration='O(', word_number=0, lemma_original='τὸν', dictionary_form_original='ὁ', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='KU/RION', type_code='N2', parse_code='ASM', dictionary_form_transliteration='KU/RIOS', word_number=0, lemma_original='κύριον', dictionary_form_original='κύριος', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='U(/MNON', type_code='N2', parse_code='ASM', dictionary_form_transliteration='U(/MNOS', word_number=0, lemma_original='ὕμνον', dictionary_form_original='ὕμνος', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='KAINO\\N', type_code='A1', parse_code='ASM', dictionary_form_transliteration='KAINO/S', word_number=0, lemma_original='καινὸν', dictionary_form_original='καινός', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='YA/LATE', type_code='VB', parse_code='AAD2P', dictionary_form_transliteration='YA/LLW', word_number=0, lemma_original='ψάλατε', dictionary_form_original='ψάλλω', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='TW=|', type_code='RA', parse_code='DSM', dictionary_form_transliteration='O(', word_number=0, lemma_original='τῷ', dictionary_form_original='ὁ', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='QEW=|', type_code='N2', parse_code='DSM', dictionary_form_transliteration='QEO/S', word_number=0, lemma_original='θεῷ', dictionary_form_original='θεός', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='TW=|', type_code='RA', parse_code='DSM', dictionary_form_transliteration='O(', word_number=0, lemma_original='τῷ', dictionary_form_original='ὁ', other_transliteration='', other_original=None, meta=None), Token(lemma_transliteration='AI)NETW=|', type_code='A1', parse_code='DSM', dictionary_form_transliteration='AI)NETO/S', word_number=0, lemma_original='αἰνετῷ', dictionary_form_original='αἰνετός', other_transliteration='', other_original=None, meta=None)], sentence_number= ...

# %%
doc = load_morph_file(test_file, 'Genesis 1:1', 'greek', 'catss')

# %%
doc.print_all()

# %%
for book in doc.books:
    print(book.book_name)
# Out:
# Gen

# %%
doc.meta
# Out:
# Meta(name=Genesis 1:1, language=greek, source=catss, filename=../../source_files/catss/greek_morph/01.Gen.1.mlxx, raw=Gen 1:1 E)N P [...], encoding=UTF8,offsets=(0, -1), description=None, license=None)

# %%
with open(test_file) as fd:
    for line in fd:
        print(line.strip())

# %%
'\u03b1\u0313', '\u0313\u03b1'
# Out:
# ('ἀ', '̓α')

# %%
'\u1f00'
# Out:
# 'ἀ'
