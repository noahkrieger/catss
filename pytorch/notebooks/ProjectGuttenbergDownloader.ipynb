# %%
import pandas as pd

# %%
df = pd.read_csv('sources/gutenberg/pg_catalog.csv', low_memory=False)

# %%
el = df[df.Language=='el']
el
# Out:
#        Text#  Type      Issued  \
# 4059    4100  Text  2003-05-01
# 17743  17814  Text  2006-02-21
# 17768  17839  Text  2006-02-23
# 17924  17995  Text  2006-03-15
# 17925  17996  Text  2006-03-15
# ...      ...   ...         ...
# 42442  42516  Text  2013-04-12
# 42524  42598  Text  2013-04-26
# 42626  42700  Text  2013-05-12
# 42888  42962  Text  2013-06-17
# 57553  57629  Text  2018-08-02
#
#                                                    Title Language  \
# 4059   Όραμα και Μεταμόρφωση : Μια εισαγωγή στο Ευγεν...       el
# 17743                                         Λυσιστράτη       el
# 17768                                  Οιδίπους Τύραννος       el
# 17924                                            Ηλέκτρα       el
# 17925                                     Επτά επί Θήβας       el
# ...                                                  ...      ...
# 42442                                Ύμνος εις την Αθηνά       el
# 42524  Πλουτάρχου Βίοι Παράλληλοι - Τόμος 2\r\nΣόλων ...       el
# 42626  Πλουτάρχου Βίοι Παράλληλοι - Τόμος 3\r\nΑλκιβι...       el
# 42888                               Παραμύθι χωρίς όνομα       el
# 57553            Lucian's Dialogues prepared for schools       el
#
#                                                  Authors  \
# 4059   Sangharakshita, Bhikshu, 1925-; Doikas, Spiros...
# 17743  Aristophanes, 446? BCE-385? BCE; Demetrakopoul...
# 17768  Sophocles, 495? BCE-406 BCE; Kampanis, Aristos...
# 17924  Euripides, 480? BCE-406 BCE; Tanagras, Angelos...
# 17925  Aeschylus, 525 BCE-456 BCE; Grypares, I. N. (I...
# ...                                                  ...
# 42442                         Palamas, Kostes, 1859-1943
# 42524  Plutarch, 46-120?; Rankaves, Alexandros Rizos,...
# 42626  Plutarch, 46-120?; Rankaves, Alexandros Rizos,...
# 42888               Delta, Penelope Stephanou, 1874-1941
# 57553  Lucian, of Samosata, 120-180; Rouse, W. H. D. ...
#
#                                                 Subjects LoCC  \
# 4059   Sangharakshita, Bhikshu, 1925-; Religious life...   BQ
# 17743  Comedies; Lysistrata (Fictitious character) --...   PA
# 17768  Tragedies; Oedipus (Greek mythological figure)...   PA
# 17924       Electra (Greek mythological figure) -- Drama   PA
# 17925  Tragedies; Seven against Thebes (Greek mytholo...   PA
# ...                                                  ...  ...
# 42442                               Greek poetry, Modern   PA
# 42524  Greece -- Biography -- Early works to 1800; Ro...   PA
# 42626  Greece -- Biography -- Early works to 1800; Ro...   PA
# 42888                 Children's stories, Greek (Modern)   PZ
# 57553  Dialogues, Greek; Greek language -- Study and ...   PA
#
#                                              Bookshelves
# 4059                                                 NaN
# 17743  Classical Antiquity; Banned Books from Anne Ha...
# 17768                                                NaN
# 17924                                Classical Antiquity
# 17925                                Classical Antiquity
# ...                                                  ...
# 42442                                                NaN
# 42524                                                NaN
# 42626                                                NaN
# 42888                                                NaN
# 57553                                                NaN
#
# [216 rows x 9 columns]

# %%
authors = list(el.Authors)
authors
# Out:
# ['Sangharakshita, Bhikshu, 1925-; Doikas, Spiros [Translator]',
#  'Aristophanes, 446? BCE-385? BCE; Demetrakopoulos, Polyvios, 1864-1922 [Translator]',
#  'Sophocles, 495? BCE-406 BCE; Kampanis, Aristos, 1883-1956 [Translator]',
#  'Euripides, 480? BCE-406 BCE; Tanagras, Angelos, 1877-1964 [Translator]',
#  'Aeschylus, 525 BCE-456 BCE; Grypares, I. N. (Ioannes N.), 1870-1942 [Translator]',
#  'Chatzopoulos, Kostantinos, 1868-1920',
#  'Sophocles, 495? BCE-406 BCE; Chrestomanos, Konstantinos, 1867-1911 [Translator]',
#  'Euripides, 480? BCE-406 BCE; Fragkias, Ioannis [Translator]',
#  'Chrestomanos, Konstantinos, 1867-1911',
#  'Rhoides, Emmanouel D., 1835-1904',
#  'Aristophanes, 446? BCE-385? BCE; Demetrakopoulos, Polyvios, 1864-1922 [Translator]',
#  'Euripides, 480? BCE-406 BCE; Demetrakopoulos, Polyvios, 1864-1922 [Translator]',
#  'Aristophanes, 446? BCE-385? BCE',
#  'Euripides, 480? BCE-406 BCE; Tsokopoulos, George B., 1871-1923 [Translator]',
#  'Aristophanes, 446? BCE-385? BCE; Demetrakopoulos, Polyvios, 1864-1922 [Translator]',
#  'Rhoides, Emmanouel D., 1835-1904',
#  'Aristotle, 384 BCE-322 BCE; Gratsiatos, Paulos [Translator]',
#  'Euripides, 480? BCE-406 BCE; Tsokopoulos, George B., 1871-1923 [Translator]',
#  'Aristotle, 384 BCE-322 BCE; Gratsiatos, Paulos [Translator]',
#  'Aristotle, 384 BCE-322 BCE; Gratsiatos, Paulos [Translator]',
#  'Lucian, of Samosata, 120-180; Kondylakes, Ioannes, 1861-1920 [Translator]',
#  'Euripides, 480? BCE-406 BCE; Tsokopoulos, George B., 1871-1923 [Translator]',
#  'Lucian, of Samosata, 120-180; Kondylakes, Ioannes, 1861-1920 [Translator]',
#  'Lucian, of Samosata, 120-180; Kondylakes, Ioannes, 1861-1920 [Translator]',
#  'Lucian, of Samosata, 120-180; Kondylakes, Ioannes, 1861-1920 [Translator]',
#  'Lucian, of Samosata, 120-180; Kondylakes, Ioannes, 1861-1920 [Translator]',
#  'Aristotle, 384 BCE-322 BCE; Zambas, Kyriakos, 1866- [Translator]',
#  'Deledda, Grazia, 1871-1936; Kotara, Lita [Editor]; Alexandridis, Christos [Translator]',
#  'Golfis, Rigas, 1886-1958',
#  'Aristotle, 384 BCE-322 BCE; Zambas, Kyriakos, 1866- [Translator]',
#  'Parren, Kalliroe, 1859-1940',
#  'Vikelas, Demetrios, 1835-1908',
#  'Thucydides, 455? BCE-395 BCE; Zervos, I. (Ioannes), 1875-1944 [Translator]',
#  'Thucydides, 455? BCE-395 BCE; Zervos, I. (Ioannes), 1875-1944 [Translator]',
#  'Thucydides, 455? BCE-395 BCE; Zervos, I. (Ioannes), 1875-1944 [Translator]',
#  'Thucydides, 455? BCE-395 BCE; Zervos, I. (Ioannes), 1875-1944 [Translator]',
#  'Homer, 750? BCE-650? BCE; Polylas, Iakovos, 1826-1898 [Translator]',
#  'Homer, 750? BCE-650? BCE; Polylas, Iakovos, 1826-1898 [Translator]',
#  'Homer, 750? BCE-650? BCE; Polylas, Iakovos, 1826-1898 [Translator]',
#  'Homer, 750? BCE-650? BCE; Polylas, Iakovos, 1826-1898 [Translator]',
#  'Aristophanes, 446? BCE-385? BCE; Demetrakopoulos, Polyvios, 1864-1922 [Translator]',
#  'Plato, 427? BCE-347? BCE; Lymperopoulos, A. [Translator]; Manesis, George D. [Translator]',
#  'Plato, 427? BCE-347? BCE; Moraitides, Alexandros, 1850-1929 [Translator]',
#  'Plato, 427? BCE-347? BCE; Harokopos, Aristeidis, 1851- [Translator]; Konstantinidis, K. D. [Translator]',
#  'Rodokanakes, Platon, 1883-1919',
#  'Plato, 427? BCE-347? BCE; Grypares, I. N. (Ioannes N.), 1870-1942 [Translator]; Harokopos, Aristeidis, 1851- [Translator]',
#  'Chatzopoulos, Kostantinos, 1868-1920',
#  'Velaras, Ioannes, 1771-1823',
#  'Shakespeare, William, 1564-1616; Polylas, Iakovos, 1826-1898 [Translator]',
#  'Vyzantios, D. K. (Demetrios Konstantinou), 1790-1853',
#  'Goethe, Johann Wolfgang von, 1749-1832; Chatzopoulos, Kostantinos, 1868-1920 [Translator]',
#  'Plato, 427? BCE-347? BCE; Zambas, Kyriakos, 1866- [Translator]',
#  'Chatzopoulos, Kostantinos, 1868-1920',
#  'Polemes, Ioannes, 1862-1924',
#  'Brugman, Karl, 1849-1919; Palles, Alexandros, 1851-1935 [Translator]',
#  'Vyzantios, D. K. (Demetrios Konstantinou), 1790-1853',
#  'Karkavitsas, Andreas, 1866-1922',
#  'Karkavitsas, Andreas, 1866-1922',
#  'Karkavitsas, Andreas, 1866-1922',
#  'Andersen, H. C. (Hans Christian), 1805-1875; Vikelas, Demetrios, 1835-1908',
#  'Psicharis, Ioannis, 1854-1929',
#  'Karkavitsas, Andreas, 1866-1922',
#  'Papadiamantes, Alexandros, 1851-1911',
#  'Homer, 750? BCE-650? BCE; Christopoulos, Athanasios, 1771-1847 [Translator]',
#  'Shakespeare, William, 1564-1616; Polylas, Iakovos, 1826-1898 [Translator]',
#  'Palles, Alexandros, 1851-1935 [Translator]',
#  'Shakespeare, William, 1564-1616; Vikelas, Demetrios, 1835-1908 [Translator]',
#  'Velaras, Ioannes, 1771-1823',
#  'Souris, Georgios, 1853-1919',
#  'Souris, Georgios, 1853-1919',
#  'Karkavitsas, Andreas, 1866-1922',
#  'Nirvanas, Paulos, 1866-1937',
#  'Papadopoulou, Arsinoe, 1853-1943',
#  'Faltaits, Kostas, 1891-1944',
#  'Eftaliotis, Argyris, 1849-1923',
#  'Christovasilis, Christos, 1862?-1937',
#  'Shakespeare, William, 1564-1616; Vikelas, Demetrios, 1835-1908 [Translator]',
#  'Nirvanas, Paulos, 1866-1937',
#  'Rhoides, Emmanouel D., 1835-1904',
#  'Virgil, 70 BCE-19 BCE; Theotokes, Konstantinos, 1872-1923 [Translator]',
#  'Wilde, Oscar, 1854-1900; Hatzigavriil, M. [Translator]',
#  'Chatzopoulos, D., 1872-1936',
#  'Krystalles, Kostas, 1868-1894',
#  'Souris, Georgios, 1853-1919',
#  'Demetrakopoulos, Polyvios, 1864-1922',
#  'Shakespeare, William, 1564-1616; Vikelas, Demetrios, 1835-1908 [Translator]',
#  'Christovasilis, Christos, 1862?-1937',
#  'Kondylakes, Ioannes, 1861-1920',
#  'Pasagiannes, Kostes G., 1872-1933',
#  'Valaorites, Aristoteles, 1824-1879; Lampros, Paulos, 1819-1887 [Other]',
#  'Melas, Leon, 1812-1879',
#  'Papadiamantes, Alexandros, 1851-1911',
#  'Papadiamantes, Alexandros, 1851-1911',
#  'Farrar, F. W. (Frederic William), 1831-1903; Papadiamantes, Alexandros, 1851-1911 [Translator]',
#  'Molière, 1622-1673; Polemes, Ioannes, 1862-1924 [Translator]',
#  'Geijerstam, Gustaf af, 1858-1909; Chatzopoulos, Kostantinos, 1868-1920 [Translator]',
#  'Eftaliotis, Argyris, 1849-1923',
#  'Vikelas, Demetrios, 1835-1908',
#  'Shakespeare, William, 1564-1616; Damiralis, Michael, 1892-1941 [Translator]',
#  'Andreadis, Andreas, 1876-1935',
#  'Eftaliotis, Argyris, 1849-1923',
#  'Nirvanas, Paulos, 1866-1937',
#  'Vizyenos, G. M. (Georgios M.), 1849-1896',
#  'Krystalles, Kostas, 1868-1894',
#  'Kalvos, Andreas, 1792-1869; Martelaos, Antonios, 1754-1819',
#  'Kondylakes, Ioannes, 1861-1920',
#  'Shakespeare, William, 1564-1616; Vikelas, Demetrios, 1835-1908 [Translator]',
#  'Krystalles, Kostas, 1868-1894',
#  'Papadiamantes, Alexandros, 1851-1911',
#  'Wilde, Oscar, 1854-1900; Marpoutzoglou, Alex G. [Translator]',
#  'Plato, 427? BCE-347? BCE; Harokopos, Aristeidis, 1851- [Translator]',
#  'Theocritus, 300 BCE-260 BCE; Polemes, Ioannes, 1862-1924 [Translator]',
#  'Plato, 427? BCE-347? BCE; Harokopos, Aristeidis, 1851- [Translator]',
#  'Plato, 427? BCE-347? BCE; Zambas, Kyriakos, 1866- [Translator]',
#  'Plato, 427? BCE-347? BCE; Zambas, Kyriakos, 1866- [Translator]',
#  'Plato, 427? BCE-347? BCE; Papantoniou, Ch. [Translator]',
#  'Plato, 427? BCE-347? BCE; Zambas, Kyriakos, 1866- [Translator]',
#  'Plato, 427? BCE-347? BCE; Zambas, Kyriakos, 1866- [Translator]',
#  'Kondylakes, Ioannes, 1861-1920',
#  'Plato, 427? BCE-347? BCE; Zambas, Kyriakos, 1866- [Translator]',
#  'Papantoniou, Zacharias L., 1877-1940',
#  'Voltaire, 1694-1778',
#  'Bédier, Joseph, 1864-1938; Ventiris, Nikolaos [Translator]',
#  'Plato, 427? BCE-347? BCE; Gratsiatos, Paulos [Translator]',
#  'Sienkiewicz, Henryk, 1846-1916',
#  'Plato, 427? BCE-347? BCE; Gounaris, K. [Translator]',
#  'Kondylakes, Ioannes, 1861-1920',
#  'Plato, 427? BCE-347? BCE; Kountouriotes, Nikolaos [Translator]',
#  'Papadiamantes, Alexandros, 1851-1911',
#  'Plato, 427? BCE-347? BCE; Gratsiatos, Paulos [Translator]',
#  'Plato, 427? BCE-347? BCE; Zambas, Kyriakos, 1866- [Translator]',
#  'Karolides, Paulos, 1849-1930',
#  'Karolides, Paulos, 1849-1930',
#  'Plato, 427? BCE-347? BCE; Zambas, Kyriakos, 1866- [Translator]',
#  'Dragoumes, Ion, 1878-1920; Tankopoulos, Demetrios P., 1867-1926 [Editor]',
#  'Plato, 427? BCE-347? BCE; Zambas, Kyriakos, 1866- [Translator]',
#  'Papadiamantes, Alexandros, 1851-1911',
#  'Homer, 750? BCE-650? BCE; Palles, Alexandros, 1851-1935 [Translator]',
#  'Plato, 427? BCE-347? BCE; Zambas, Kyriakos, 1866- [Translator]',
#  'Rhoides, Emmanouel D., 1835-1904',
#  'Plato, 427? BCE-347? BCE; Zambas, Kyriakos, 1866- [Translator]',
#  'Axiotes, Pan. (Panagiotes), 1840-1918',
#  nan,
#  nan,
#  nan,
#  'Papadiamantes, Alexandros, 1851-1911',
#  'Goethe, Johann Wolfgang von, 1749-1832; Aretas, Ioannis [Translator]',
#  'Molière, 1622-1673; Polemes, Ioannes, 1862-1924 [Translator]',
#  'Marx, Karl, 1818-1883; Pareto, Vilfredo, 1848-1923 [Commentator]',
#  'Rostand, Edmond, 1868-1918; Stratigis, George, 1860-1938 [Translator]',
#  'Ainian, Demetrios, 1800-1881',
#  'Moraitides, Alexandros, 1850-1929',
#  'Longus; Voutierides, El. P.\u200f (Elias P.), 1874-1941 [Translator]',
#  'Moraitides, Alexandros, 1850-1929',
#  'Poe, Edgar Allan, 1809-1849; Spandones, N. (Nikolaos), 1858-1913 [Translator]',
#  'Moraitides, Alexandros, 1850-1929',
#  'Moraitides, Alexandros, 1850-1929',
#  'Gogol, Nikolai Vasilevich, 1809-1852; Sukhovo-Kobylin, A. (Aleksandr), 1817-1903; Konstantinidis, Agathoklis, 1854-1920 [Translator]',
#  'Andersen, H. C. (Hans Christian), 1805-1875; Chatziarapi, Anastasia [Translator]',
#  'Flaubert, Gustave, 1821-1880; Simiriotis, S. [Translator]',
#  'Vlachos, Angelos, 1838-1920',
#  'Herodotus, 480? BCE-420? BCE',
#  'Herodotus, 480? BCE-420? BCE',
#  'Karkavitsas, Andreas, 1866-1922',
#  'Trikoupes, Spyridon, 1788-1873',
#  'Trikoupes, Spyridon, 1788-1873',
#  'Trikoupes, Spyridon, 1788-1873',
#  'Cottin, Madame (Sophie), 1770-1807; Argyropoulos, K. P. [Translator]',
#  'Prévost, Marcel, 1862-1941; Economopoulos, Elias, 1868-1929 [Translator]',
#  'Tolstoy, Leo, graf, 1828-1910; Economopoulos, Elias, 1868-1929 [Translator]',
#  'Kampyses, Giannes, 1872-1901',
#  'Trikoupes, Spyridon, 1788-1873',
#  'Aeschylus, 525 BCE-456 BCE; Grypares, I. N. (Ioannes N.), 1870-1942 [Translator]',
#  'Phlores, Kostas',
#  'Aeschylus, 525 BCE-456 BCE; Grypares, I. N. (Ioannes N.), 1870-1942 [Translator]',
#  'Polemes, Ioannes, 1862-1924',
#  'Aeschylus, 525 BCE-456 BCE; Zervos, I. (Ioannes), 1875-1944 [Translator]',
#  'Euripides, 480? BCE-406 BCE; Voutierides, El. P.\u200f (Elias P.), 1874-1941 [Translator]',
#  'Vrailas-Armenes, Petros, 1813?-1884',
#  'Sophocles, 495? BCE-406 BCE; Voutierides, El. P.\u200f (Elias P.), 1874-1941 [Translator]',
#  'Aeschylus, 525 BCE-456 BCE; Zervos, I. (Ioannes), 1875-1944 [Translator]',
#  'Verne, Jules, 1828-1905',
#  'Plato, 427? BCE-347? BCE; Moraitides, Alexandros, 1850-1929 [Translator]',
#  'Plato, 427? BCE-347? BCE; Grypares, I. N. (Ioannes N.), 1870-1942 [Translator]',
#  'Plato, 427? BCE-347? BCE; Grypares, I. N. (Ioannes N.), 1870-1942 [Translator]',
#  'Plato, 427? BCE-347? BCE; Grypares, I. N. (Ioannes N.), 1870-1942 [Translator]',
#  'Plato, 427? BCE-347? BCE; Grypares, I. N. (Ioannes N.), 1870-1942 [Translator]',
#  'Aeschylus, 525 BCE-456 BCE; Grypares, I. N. (Ioannes N.), 1870-1942 [Translator]',
#  'Papantoniou, Ch.',
#  'Tagore, Rabindranath, 1861-1941; Trikoglides, K. [Translator]',
#  'Plato, 427? BCE-347? BCE; Zervos, I. (Ioannes), 1875-1944 [Translator]',
#  'Xenophon, 431 BCE-350? BCE; Anastasopoulos, Demetrios, 1873- [Translator]',
#  'Aristotle, 384 BCE-322 BCE; Zervos, I. (Ioannes), 1875-1944 [Translator]',
#  'Xenophon, 431 BCE-350? BCE; Anastasopoulos, Demetrios, 1873- [Translator]',
#  nan,
#  'Trikoglides, K. [Translator]',
#  'Vrokines, Laurentios S., 1847-1910',
#  'Karolides, Paulos, 1849-1930',
#  'Verne, Jules, 1828-1905; Phermpos, Panagiotes I., 1851-1932 [Translator]',
#  'Karolides, Paulos, 1849-1930',
#  'Anninos, Bampes, 1852-1934',
#  'Karolides, Paulos, 1849-1930',
#  'Euangelides, Tryphon E., 1863-1941',
#  'Solomos, Dionysios, 1798-1857',
#  'Papadiamantes, Alexandros, 1851-1911',
#  'Murray, Gilbert, 1866-1957; Menardos, Simos, 1872-1933 [Translator]',
#  'Plutarch, 46-120?; Rankaves, Alexandros Rizos, 1809-1892 [Translator]',
#  'Marmontel, Jean-François, 1723-1799; Pangalos, Alexandros [Translator]',
#  'Stamatiades, Epameinondas I., 1835-1901',
#  'Palamas, Kostes, 1859-1943',
#  'Palamas, Kostes, 1859-1943',
#  'Palamas, Kostes, 1859-1943',
#  'Plutarch, 46-120?; Rankaves, Alexandros Rizos, 1809-1892 [Translator]',
#  'Plutarch, 46-120?; Rankaves, Alexandros Rizos, 1809-1892 [Translator]',
#  'Delta, Penelope Stephanou, 1874-1941',
#  'Lucian, of Samosata, 120-180; Rouse, W. H. D. (William Henry Denham), 1863-1950 [Editor]']
